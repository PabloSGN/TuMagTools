# %%
# ============================ IMPORTS ====================================== #

# Built-in libs 
import os
import sys
import glob
import numpy as np

import matplotlib.pyplot as plt

# Own libs
from utils import read_Tumag
import MicroPols_extractor as mpe
 
# ============================= CONFIG ====================================== #

plt.style.use('dark_background')

#Remember to update the folder!!!!!
MainFolder = r"LightTest"
# =========================================================================== #

# %%
all_ims = sorted(glob.glob(os.path.join(MainFolder, "*img")))
print(f"Images found : {len(all_ims)}")
# Out:
# Images found : 50

# %% [markdown]
# ## Select configuration of analysis
#
# - Selected sets of the MicroPols (0 - 16) (labeled in image) - In an array
# - Select polarization angle - Int : 0, 90, 45 or 135
# - The image will show the selected regions of the image. (Red for the micropols set and a black box for the polarization ngle selected.)

# %%
mpe.plot_configuration(MainFolder, [5, 9, 2, 15], 90)

# %%
mpe.get_modulation_curve(MainFolder, [2, 5, 9, 15], 135)
mpe.get_modulation_curve(MainFolder, [2, 5, 9, 15], 45)
mpe.get_modulation_curve(MainFolder, [2, 5, 9, 15], 90)
mpe.get_modulation_curve(MainFolder, [2, 5, 9, 15], 135)
# Out:
# Images found : 50
# Selected Sets: [2, 5, 9, 15]
# Selected pol angle: 135
# Images found : 50
# Selected Sets: [2, 5, 9, 15]
# Selected pol angle: 45
# Images found : 50
# Selected Sets: [2, 5, 9, 15]
# Selected pol angle: 90
# Images found : 50
# Selected Sets: [2, 5, 9, 15]
# Selected pol angle: 135
